# %% [markdown]
# Se extraen los datos

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
#extrayendo los datos
fallos=pd.read_csv("C:/Users/Rulig/OneDrive/Escritorio/apps/progra/python/PCD/heart_failure_clinical_records.csv")
columnas=fallos[:-1]
plt.style.use('dark_background')

# %% [markdown]
# Se realizan las definiciones de las funciones

# %%
def mean(dataset):
  return(sum(dataset)/len(dataset))

def calcular_varianza(datos):
    n = len(datos)
    media = sum(datos) / n
    suma_cuadrados = sum((x - media) ** 2 for x in datos)
    varianza = suma_cuadrados / (n - 1)  # Usamos (n-1) para la varianza muestral
    return varianza

def calcular_covarianza(X, Y):
    n = len(X)
    media_X = sum(X) / n
    media_Y = sum(Y) / n
    suma_productos = sum((X[i] - media_X) * (Y[i] - media_Y) for i in range(n))
    covarianza = suma_productos / (n - 1)  # Usamos (n-1) para la covarianza muestral
    return covarianza

def calcular_coeficiente_correlacion(X, Y):
    covarianza = calcular_covarianza(X, Y)
    desviacion_X = (calcular_varianza(X)) ** 0.5
    desviacion_Y = (calcular_varianza(Y)) ** 0.5
    coeficiente_correlacion = covarianza / (desviacion_X * desviacion_Y)
    return coeficiente_correlacion

def calcular_matrices_cov_cor(X, Y):
    # Calcula la covarianza
    n = len(X)
    media_X = sum(X) / n
    media_Y = sum(Y) / n
    suma_productos = sum((X[i] - media_X) * (Y[i] - media_Y) for i in range(n))
    covarianza = suma_productos / (n - 1)  # Usamos (n-1) para la covarianza muestral

    # Calcula la matriz de covarianzas
    matriz_covarianzas = [[0] * 2 for _ in range(2)]
    matriz_covarianzas[0][0] = calcular_varianza(X)
    matriz_covarianzas[1][1] = calcular_varianza(Y)
    matriz_covarianzas[0][1] = covarianza
    matriz_covarianzas[1][0] = covarianza

    # Calcula la matriz de correlación
    desviacion_X = (matriz_covarianzas[0][0]) ** 0.5
    desviacion_Y = (matriz_covarianzas[1][1]) ** 0.5
    matriz_correlacion = [[0] * 2 for _ in range(2)]
    matriz_correlacion[0][0] = 1.0
    matriz_correlacion[1][1] = 1.0
    matriz_correlacion[0][1] = covarianza / (desviacion_X * desviacion_Y)
    matriz_correlacion[1][0] = matriz_correlacion[0][1]

    return matriz_covarianzas, matriz_correlacion

def multimode(dataset):
    # Contar la frecuencia de cada número
    conteo = {}
    numeros={}
    dataseto=sorted(dataset)
    for num in dataseto:
        if num in conteo:
            conteo[num] += 1
        else:
            conteo[num] = 1
    maxfrecuency=max(conteo.values())
    numeros_sin_rep = [num for num, freq in conteo.items() if freq == maxfrecuency]
    return numeros_sin_rep,maxfrecuency
def filtrado(metadata):
  id = np.zeros(len(metadata))
  for i, col in enumerate(metadata):
      x = fallos[col]
      cont = 0
      for j in range(len(x)):
          if x[j] == 1 or x[j] == 0:
              id[i] = 1
              break
  return id

def rango(dataset):
  return np.max(dataset)-np.min(dataset)

def sepbins(dataset,almacen, bins):
  print(type(dataset))
  datint=rango(dataset)/bins
  sorted_dataset=sorted(dataset)
  tamint=len(dataset)
  for j in range(0,bins):
    for i in range((len(dataset))):
      if(datint *j<=dataset[i]<=datint*(j+1)):
        almacen[j]+=1
""""
Calculando los coeficientes de la regresion lineal y el error residual

Retorna: tupla con coeficientes a_0, a_1 y el error residual r_
"""
def coef(x,y):
  s_x=sum(x)
  s_y=sum(y)
  s_xy=np.zeros(len(x))
  s_xx=np.zeros((len(x)))
  r_=0.0
  for i in range(len(x)):
    s_xy[i]=x[i]*y[i]
    s_xx[i]=x[i]*x[i]
  s_xx=sum(s_xx)
  s_xy=sum(s_xy)
  a_1=(len(x)*s_xy-s_y*s_x)/(len(x)*s_xx-(s_x)**2)
  a_0=(s_y-a_1*s_x)/len(x)
  for i in range(len(x)):
    r_=r_+(a_0+a_1*x[i]-y[i])**2
  return a_0,a_1,r_

def calcularmatrix(dataset):
   matrizcov=dataset.cov()
   matrizcorr=dataset.corr()
   return matrizcov, matrizcorr

# %% [markdown]
# Extraccion de los metadatos y realizacion de las combinaciones, como el filtrado de los datos

# %%
metadata=[col for col in columnas]
combinaciones = [(col1, col2) for col1 in columnas for col2 in columnas if col1 != col2]
resfil=filtrado(metadata)
metadata_filtradot = [col for i, col in enumerate(metadata) if resfil[i] == 1]
metadata_filtrado=[col for i, col in enumerate(metadata) if resfil[i] == 0]

# %% [markdown]
# Realizacion de calculos de media, moda y varianza

# %%
for col in enumerate(metadata):
  print(col[1])
  x=fallos[col[1]]
  print("promedio:",mean(x))
  mode,freq=multimode(x)
  print("Moda de",mode,"con una frecuencia de ",freq)
  var=calcular_varianza(x)
  print("varianza",var)
# Out:
# age
# promedio: 60.28873639999996
# Moda de [60.0] con una frecuencia de  581
# varianza 136.82548936798605
# anaemia
# promedio: 0.4744
# Moda de [0] con una frecuencia de  2628
# varianza 0.24939451890380002
# creatinine_phosphokinase
# promedio: 586.7606
# Moda de [582] con una frecuencia de  769
# varianza 954009.2655407496
# diabetes
# promedio: 0.4394
# Moda de [0] con una frecuencia de  2803
# varianza 0.24637691538307405
# ejection_fraction
# promedio: 37.7346
# Moda de [35] con una frecuencia de  771
# varianza 132.59188121624263
# high_blood_pressure
# promedio: 0.3648
# Moda de [0] con una frecuencia de  3176
# varianza 0.2317673134626846
# platelets
# promedio: 265075.404369998
# Moda de [263358.03] con una frecuencia de  395
# varianza 9603952689.891945
# serum_creatinine
# promedio: 1.3691059999999975
# Moda de [1.0] con una frecuencia de  841
# varianza 1.0195952198079479
# serum_sodium
# promedio: 136.8082
# Moda de [137] con una frecuencia de  641
# varianza 19.92939863972764
# sex
# promedio: 0.6456
# Moda de [1] con una frecuencia de  3228
# varianza 0.22884640928187142
# smoking
# promedio: 0.3118
# Moda de [0] con una frecuencia de  3441
# varianza 0.21462368473692817
# time
# promedio: 130.6788
# Moda de [74] con una frecuencia de  128
# varianza 5979.299090378005
# DEATH_EVENT
# promedio: 0.3136
# Moda de [0] con una frecuencia de  3432
# varianza 0.2152980996199092

# %% [markdown]
# Realizando plots de densidad colocando un valor de bin

# %%
bins=100
almacen=np.zeros(bins)
fig, ax = plt.subplots(len(metadata_filtrado), figsize=(5,15))
for idx, col in enumerate(metadata_filtrado):
  print(col)
  x=fallos[col]
  almacen = np.zeros(bins) 
  sepbins(x,almacen,bins)
  ax[idx].plot(almacen,label=f'{col}')
  ax[idx].grid(True)
  ax[idx].set_title(col)
# Out:
# age
# <class 'pandas.core.series.Series'>
# creatinine_phosphokinase
# <class 'pandas.core.series.Series'>
# ejection_fraction
# <class 'pandas.core.series.Series'>
# platelets
# <class 'pandas.core.series.Series'>
# serum_sodium
# <class 'pandas.core.series.Series'>
# time
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Realizando graficas de dispersion

# %%
combinaciones = [(col1, col2) for col1 in metadata_filtrado for col2 in metadata_filtrado if col1 != col2]
fig, ax = plt.subplots(len(combinaciones), figsize=(5,3*len(combinaciones)))

for idx, (col1, col2) in enumerate(combinaciones):
  x=fallos[col1]
  y=fallos[col2]
  ax[idx].scatter(x, y, label=f'{col2} vs {col1}')
  ax[idx].legend()
  ax[idx].set_xlabel(col1)
  ax[idx].set_ylabel(col2)

# %% [markdown]
# Realizando su regresion lineal

# %%
fig, ax = plt.subplots(len(combinaciones),figsize=(5,3*len(combinaciones)))
for idx, (col1, col2) in enumerate(combinaciones):
  x=fallos[col1]
  y=fallos[col2]
  ax[idx].scatter(x, y, label=f'{col2} vs {col1}')
  ax[idx].legend()
  a_0,a_1,r_1=coef(x,y)
  yprime=a_0+np.dot(a_1,x)
  ax[idx].plot(x,yprime,'r')

# %% [markdown]
# Realizando calculos de coeficiente de correlacion y covarianza

# %%
for idx, (col1, col2) in enumerate(combinaciones):
  x=fallos[col1]
  y=fallos[col2]
  cov=calcular_covarianza(x,y)
  print("metadatos ",col1,col2)
  print("covarianza",cov)  
  corr=calcular_coeficiente_correlacion(x,y)
  print("coeficiente correlacion",corr)
  if corr == 1:
     print("Correlación perfecta")
  elif corr == -1:
     print("Anticorrelación perfecta")
  elif corr == 0:
     print("Descorrelación")
  elif 0.7 <= corr < 1:
     print("Correlación alta positiva")
  elif -1 < corr <= -0.7:
     print("Correlación alta negativa")
  elif 0.3 <= corr < 0.7:
     print("Correlación moderada positiva")
  elif -0.7 < corr <= -0.3:
     print("Correlación moderada negativa")
  elif 0 < corr < 0.3:
     print("Correlación baja positiva")
  elif -0.3 < corr < 0:
     print("Correlación baja negativa")
  else:
     print("Valor inesperado de correlación")
# Out:
# metadatos  age creatinine_phosphokinase
# covarianza -738.4808652788948
# coeficiente correlacion -0.06463674015754794
# Correlación baja negativa
# metadatos  age ejection_fraction
# covarianza 9.344962433046575
# coeficiente correlacion 0.06938020657232191
# Correlación baja positiva
# metadatos  age platelets
# covarianza -28610.691176573244
# coeficiente correlacion -0.02495857802896618
# Correlación baja negativa
# metadatos  age serum_sodium
# covarianza -1.3672302045209073
# coeficiente correlacion -0.026182495765112557
# Correlación baja negativa
# metadatos  age time
# covarianza -199.15483083448396
# coeficiente correlacion -0.2201821973136391
# Correlación baja negativa
# metadatos  creatinine_phosphokinase age
# covarianza -738.4808652788948
# coeficiente correlacion -0.06463674015754794
# Correlación baja negativa
# metadatos  creatinine_phosphokinase ejection_fraction
# covarianza -236.26558987797318
# coeficiente correlacion -0.02100708111024482
# Correlación baja negativa
# metadatos  creatinine_phosphokinase platelets
# covarianza 2374741.8618205492
# coeficiente correlacion 0.024809333987281502
# Correlación baja positiva
# metadatos  creatinine_phosphokinase serum_sodium
# covarianza 224.1391109021806
# coeficiente correlacion 0.05140368474160228
# Correlación baja positiva
# metadatos  creatinine_phosphokinase time
# covarianza -1041.4043761552314
# coeficiente correlacion -0.013788529832460013
# Correlación baja negativa
# metadatos  ejection_fraction age
# covarianza 9.344962433046575
# coeficiente correlacion 0.06938020657232191
# Correlación baja positiva
# metadatos  ejection_fraction creatinine_phosphokinase
# covarianza -236.26558987797318
# coeficiente correlacion -0.02100708111024482
# Correlación baja negativa
# metadatos  ejection_fraction platelets
# covarianza 68032.94902160167
# coeficiente correlacion 0.06028868683734632
# Correlación baja positiva
# metadatos  ejection_fraction serum_sodium
# covarianza 10.930082296459254
# coeficiente correlacion 0.21262673409987476
# Correlación baja positiva
# metadatos  ejection_fraction time
# covarianza 60.96714694938994
# coeficiente correlacion 0.06847188231144613
# Correlación baja positiva
# metadatos  platelets age
# covarianza -28610.691176573244
# coeficiente correlacion -0.02495857802896618
# Correlación baja negativa
# metadatos  platelets creatinine_phosphokinase
# covarianza 2374741.8618205492
# coeficiente correlacion 0.024809333987281502
# Correlación baja positiva
# metadatos  platelets ejection_fraction
# covarianza 68032.94902160167
# coeficiente correlacion 0.06028868683734632
# Correlación baja positiva
# metadatos  platelets serum_sodium
# covarianza 17981.621064378956
# coeficiente correlacion 0.04110141164779133
# Correlación baja positiva
# metadatos  platelets time
# covarianza -7764.959956347179
# coeficiente correlacion -0.0010246819250943153
# Correlación baja negativa
# metadatos  serum_sodium age
# covarianza -1.3672302045209073
# coeficiente correlacion -0.026182495765112557
# Correlación baja negativa
# metadatos  serum_sodium creatinine_phosphokinase
# covarianza 224.1391109021806
# coeficiente correlacion 0.05140368474160228
# Correlación baja positiva
# metadatos  serum_sodium ejection_fraction
# covarianza 10.930082296459254
# coeficiente correlacion 0.21262673409987476
# Correlación baja positiva
# metadatos  serum_sodium platelets
# covarianza 17981.621064378956
# coeficiente correlacion 0.04110141164779133
# Correlación baja positiva
# metadatos  serum_sodium time
# covarianza 37.87256835367107
# coeficiente correlacion 0.10971159326514159
# Correlación baja positiva
# metadatos  time age
# covarianza -199.15483083448396
# coeficiente correlacion -0.2201821973136391
# Correlación baja negativa
# metadatos  time creatinine_phosphokinase
# covarianza -1041.4043761552314
# coeficiente correlacion -0.013788529832460013
# Correlación baja negativa
# metadatos  time ejection_fraction
# covarianza 60.96714694938994
# coeficiente correlacion 0.06847188231144613
# Correlación baja positiva
# metadatos  time platelets
# covarianza -7764.959956347179
# coeficiente correlacion -0.0010246819250943153
# Correlación baja negativa
# metadatos  time serum_sodium
# covarianza 37.87256835367107
# coeficiente correlacion 0.10971159326514159
# Correlación baja positiva

# %% [markdown]
# Realizando la matriz de correlaccion

# %%
fig = plt.figure(figsize=(25, 10))

gs = fig.add_gridspec(1, 1)

gs.update(wspace=0.3, hspace=0.15)

ax = fig.add_subplot(gs[0, 0])

ax.set_title("Matriz de Correlacion", fontsize=28, fontweight='bold', fontfamily='Comic Sans MS', color="#fff")

sns.heatmap(fallos.corr().transpose(), mask=np.triu(np.ones_like(fallos.corr().transpose())), fmt=".1f", annot=True, cmap='Blues')

plt.show()

# %% [markdown]
# Matrices calculo

# %%
matcov,matcor=calcularmatrix(fallos)
print(matcov)
print(matcor)
# Out:
#                                    age      anaemia  creatinine_phosphokinase
# age                         136.825489     0.719104             -7.384809e+02  \
# anaemia                       0.719104     0.249395             -8.873698e+01
# creatinine_phosphokinase   -738.480865   -88.736976              9.540093e+05
# diabetes                     -0.580250     0.000549             -9.689946e+00
# ejection_fraction             9.344962     0.134933             -2.362656e+02
# high_blood_pressure           0.521775     0.011341             -2.154618e+01
# platelets                -28610.691177 -2268.040173              2.374742e+06
# serum_creatinine              2.104702     0.016309             -3.976805e+00
# serum_sodium                 -1.367230     0.046199              2.241391e+02
# sex                           0.406141    -0.019477              3.255727e+01
# smoking                       0.127531    -0.024523             -6.467849e+00
# time                       -199.154831    -4.288280             -1.041404e+03
# DEATH_EVENT                   1.353857     0.012631              3.612310e+01
#
#                              diabetes  ejection_fraction  high_blood_pressure
# age                         -0.580250           9.344962             0.521775  \
# anaemia                      0.000549           0.134933             0.011341
# creatinine_phosphokinase    -9.689946        -236.265590           -21.546176
# diabetes                     0.246377          -0.280639            -0.008295
# ejection_fraction           -0.280639         132.591881             0.119042
# high_blood_pressure         -0.008295           0.119042             0.231767
# platelets                 3511.940972       68032.949022          2266.672630
# serum_creatinine            -0.009559          -0.447327            -0.003579
# serum_sodium                -0.237971          10.930082             0.141597
# sex                         -0.036484          -0.621582            -0.020519
# smoking                     -0.038413          -0.114271            -0.005746
# time                         1.053746          60.967147            -6.829192
# DEATH_EVENT                 -0.002596          -1.563883             0.021003
#
#                              platelets  serum_creatinine  serum_sodium
# age                      -2.861069e+04          2.104702     -1.367230  \
# anaemia                  -2.268040e+03          0.016309      0.046199
# creatinine_phosphokinase  2.374742e+06         -3.976805    224.139111
# diabetes                  3.511941e+03         -0.009559     -0.237971
# ejection_fraction         6.803295e+04         -0.447327     10.930082
# high_blood_pressure       2.266673e+03         -0.003579      0.141597
# platelets                 9.603953e+09       -512.397641  17981.621064
# serum_creatinine         -5.123976e+02          1.019595     -1.035357
# serum_sodium              1.798162e+04         -1.035357     19.929399
# sex                      -4.463479e+03          0.020485     -0.114997
# smoking                   2.951853e+03          0.001417     -0.028602
# time                     -7.764960e+03        -14.873332     37.872568
# DEATH_EVENT              -1.433334e+03          0.145844     -0.470946
#
#                                   sex      smoking         time  DEATH_EVENT
# age                          0.406141     0.127531  -199.154831     1.353857
# anaemia                     -0.019477    -0.024523    -4.288280     0.012631
# creatinine_phosphokinase    32.557268    -6.467849 -1041.404376    36.123100
# diabetes                    -0.036484    -0.038413     1.053746    -0.002596
# ejection_fraction           -0.621582    -0.114271    60.967147    -1.563883
# high_blood_pressure         -0.020519    -0.005746    -6.829192     0.021003
# platelets                -4463.479409  2951.853036 -7764.959956 -1433.333819
# serum_creatinine             0.020485     0.001417   -14.873332     0.145844
# serum_sodium                -0.114997    -0.028602    37.872568    -0.470946
# sex                          0.228846     0.096321    -0.318697     0.012342
# smoking                      0.096321     0.214624    -0.489348     0.002020
# time                        -0.318697    -0.489348  5979.299090   -18.916855
# DEATH_EVENT                  0.012342     0.002020   -18.916855     0.215298
#                                age   anaemia  creatinine_phosphokinase
# age                       1.000000  0.123102                 -0.064637  \
# anaemia                   0.123102  1.000000                 -0.181922
# creatinine_phosphokinase -0.064637 -0.181922                  1.000000
# diabetes                 -0.099938  0.002214                 -0.019987
# ejection_fraction         0.069380  0.023465                 -0.021007
# high_blood_pressure       0.092656  0.047172                 -0.045821
# platelets                -0.024959 -0.046343                  0.024809
# serum_creatinine          0.178194  0.032343                 -0.004032
# serum_sodium             -0.026182  0.020723                  0.051404
# sex                       0.072581 -0.081526                  0.069679
# smoking                   0.023534 -0.105996                 -0.014294
# time                     -0.220182 -0.111049                 -0.013789
# DEATH_EVENT               0.249442  0.054508                  0.079706
#
#                           diabetes  ejection_fraction  high_blood_pressure
# age                      -0.099938           0.069380             0.092656  \
# anaemia                   0.002214           0.023465             0.047172
# creatinine_phosphokinase -0.019987          -0.021007            -0.045821
# diabetes                  1.000000          -0.049101            -0.034712
# ejection_fraction        -0.049101           1.000000             0.021474
# high_blood_pressure      -0.034712           0.021474             1.000000
# platelets                 0.072198           0.060289             0.048044
# serum_creatinine         -0.019072          -0.038473            -0.007362
# serum_sodium             -0.107393           0.212627             0.065884
# sex                      -0.153649          -0.112841            -0.089096
# smoking                  -0.167046          -0.021421            -0.025762
# time                      0.027454           0.068472            -0.183450
# DEATH_EVENT              -0.011273          -0.292702             0.094023
#
#                           platelets  serum_creatinine  serum_sodium       sex
# age                       -0.024959          0.178194     -0.026182  0.072581  \
# anaemia                   -0.046343          0.032343      0.020723 -0.081526
# creatinine_phosphokinase   0.024809         -0.004032      0.051404  0.069679
# diabetes                   0.072198         -0.019072     -0.107393 -0.153649
# ejection_fraction          0.060289         -0.038473      0.212627 -0.112841
# high_blood_pressure        0.048044         -0.007362      0.065884 -0.089096
# platelets                  1.000000         -0.005178      0.041101 -0.095209
# serum_creatinine          -0.005178          1.000000     -0.229683  0.042409
# serum_sodium               0.041101         -0.229683      1.000000 -0.053848
# sex                       -0.095209          0.042409     -0.053848  1.000000
# smoking                    0.065018          0.003029     -0.013830  0.434621
# time                      -0.001025         -0.190489      0.109712 -0.008616
# DEATH_EVENT               -0.031521          0.311281     -0.227355  0.055604
#
#                            smoking      time  DEATH_EVENT
# age                       0.023534 -0.220182     0.249442
# anaemia                  -0.105996 -0.111049     0.054508
# creatinine_phosphokinase -0.014294 -0.013789     0.079706
# diabetes                 -0.167046  0.027454    -0.011273
# ejection_fraction        -0.021421  0.068472    -0.292702
# high_blood_pressure      -0.025762 -0.183450     0.094023
# platelets                 0.065018 -0.001025    -0.031521
# serum_creatinine          0.003029 -0.190489     0.311281
# serum_sodium             -0.013830  0.109712    -0.227355
# sex                       0.434621 -0.008616     0.055604
# smoking                   1.000000 -0.013660     0.009397
# time                     -0.013660  1.000000    -0.527234
# DEATH_EVENT               0.009397 -0.527234     1.000000
